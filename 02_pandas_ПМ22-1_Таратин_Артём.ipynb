# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
data = pd.read_csv('downloads/labs/sp500hst.txt', sep=",", names=["date", "ticker", "open", "high", "low", "close", "volume"])
data
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090821      A  25.60  25.6100  25.220  25.55   34758
# 1       20090824      A  25.64  25.7400  25.330  25.50   22247
# 2       20090825      A  25.50  25.7000  25.225  25.34   30891
# 3       20090826      A  25.32  25.6425  25.145  25.48   33334
# 4       20090827      A  25.50  25.5700  25.230  25.54   70176
# ...          ...    ...    ...      ...     ...    ...     ...
# 122569  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
data.loc[:, 'open':'volume'].mean()
# Out:
# open         42.595458
# high         43.102243
# low          42.054464
# close        42.601865
# volume    81395.068138
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
data['month'] = pd.DatetimeIndex(pd.to_datetime(data['date'], unit='s')).month #unit='ns' | unit='s' | unit='m'???
data
# Out:
#             date ticker   open     high     low  close  volume  month
# 0       20090821      A  25.60  25.6100  25.220  25.55   34758      8
# 1       20090824      A  25.64  25.7400  25.330  25.50   22247      8
# 2       20090825      A  25.50  25.7000  25.225  25.34   30891      8
# 3       20090826      A  25.32  25.6425  25.145  25.48   33334      8
# 4       20090827      A  25.50  25.5700  25.230  25.54   70176      8
# ...          ...    ...    ...      ...     ...    ...     ...    ...
# 122569  20100813    ZMH  51.72  51.9000  51.380  51.44   14561      8
# 122570  20100816    ZMH  51.13  51.4700  50.600  51.00   13489      8
# 122571  20100817    ZMH  51.14  51.6000  50.890  51.21   20498      8
# 122572  20100819    ZMH  51.63  51.6300  50.170  50.22   18259      8
# 122573  20100820    ZMH  50.03  50.5500  49.480  49.82   17792      8
#
# [122574 rows x 8 columns]

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
data2 = data.groupby(['ticker']).count()[['open']]
data2
# Out:
#         open
# ticker
# A        245
# AA       245
# AAPL     241
# ABC      245
# ABT      245
# ...      ...
# XTO      207
# YHOO     243
# YUM      245
# ZION     244
# ZMH      245
#
# [524 rows x 1 columns]

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
data2 = pd.read_csv('downloads/labs/sp500hst.txt', sep=",", names=["date", "ticker", "open", "high", "low", "close", "volume"])
sp_data2 = pd.read_csv('downloads/labs/sp_data2.csv', sep=';', names=['ticker', 'decoding', 'percent'], on_bad_lines='skip')

# %%
data[:3]
# Out:
#        date ticker   open   high     low  close  volume  month
# 0  20090821      A  25.60  25.61  25.220  25.55   34758      8
# 1  20090824      A  25.64  25.74  25.330  25.50   22247      8
# 2  20090825      A  25.50  25.70  25.225  25.34   30891      8

# %%
sp_data2[:3]
# Out:
#   ticker    decoding percent
# 0   AAPL       Apple    3.6%
# 1   AMZN  Amazon.com    3.2%
# 2  GOOGL    Alphabet    3.1%

# %%
data2 = data2.merge(sp_data2)
data2
# Out:
#            date ticker   open     high     low  close  volume  \
# 0      20090821      A  25.60  25.6100  25.220  25.55   34758
# 1      20090824      A  25.64  25.7400  25.330  25.50   22247
# 2      20090825      A  25.50  25.7000  25.225  25.34   30891
# 3      20090826      A  25.32  25.6425  25.145  25.48   33334
# 4      20090827      A  25.50  25.5700  25.230  25.54   70176
# ...         ...    ...    ...      ...     ...    ...     ...
# 82167  20100813   ZION  20.17  20.4300  19.840  19.89   25193
# 82168  20100816   ZION  19.81  19.9600  19.600  19.95   25914
# 82169  20100817   ZION  20.07  20.4700  19.830  20.31   31717
# 82170  20100819   ZION  19.83  20.0000  19.130  19.35   45935
# 82171  20100820   ZION  19.15  19.2700  18.810  19.14   37225
#
#                    decoding percent
# 0      Agilent Technologies    0.1%
# 1      Agilent Technologies    0.1%
# 2      Agilent Technologies    0.1%
# 3      Agilent Technologies    0.1%
# ...

# %% [markdown]
# ## Лабораторная работа №2.1

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
res = pd.read_csv('downloads/labs/recipes_sample.csv')
rew = pd.read_csv('downloads/labs/reviews_sample.csv', index_col=0)

# %%
res
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
rew
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(f'1:\n{res.shape}\n{res.dtypes}\n\n2:\n{rew.shape}\n{rew.dtypes}')
# Out:
# 1:
# (30000, 8)
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
#
# 2:
# (126696, 5)
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
res.isna().sum(axis = 0) > 0
# Out:
# name              False
# id                False
# minutes           False
# contributor_id    False
# submitted         False
# n_steps            True
# description        True
# n_ingredients      True
# dtype: bool

# %%
rew.isna().sum(axis = 0) > 0
# Out:
# user_id      False
# recipe_id    False
# date         False
# rating       False
# review        True
# dtype: bool

# %%
(res.shape[0] - res.dropna().shape[0]) / res.shape[0]
# Out:
# 0.5684666666666667

# %%
sum(res.isna().sum(axis=1) > 0) / res.shape[0]
# Out:
# 0.5684666666666667

# %%
(rew.shape[0] - rew.dropna().shape[0]) / rew.shape[0]
# Out:
# 0.00013417945317926376

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
pd.options.display.float_format = '{:.10}'.format

# %%
res.mean(axis=0, numeric_only=True)
# Out:
# id                221879.294
# minutes          123.3581333
# contributor_id   5635900.573
# n_steps          9.805582137
# n_ingredients    9.008285985
# dtype: float64

# %%
rew.mean(axis=0, numeric_only=True)
# Out:
# user_id     140801264.7
# recipe_id   160094.3871
# rating      4.410802235
# dtype: float64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
rd = np.random.randint(0, res['name'].size, 10)
res['name'][rd]
# Out:
# 29180                                          wet panther
# 28802        venezuelan scrambled eggs   perico venezolano
# 757                                 another bircher muesli
# 23500    sausage stuffed portabella mushrooms with mozz...
# 8898                                  cucumber gimlet  gin
# 25599             spinach and parmesan stuffed flank steak
# 28509                                 vanilla cherry fudge
# 13695                         herbed zucchini cheese bread
# 21456        potato  kale  and kielbasa casserole  for two
# 29941                                     zucchini lasagna
# Name: name, dtype: object

# %%
res['name'].sample(10)
# Out:
# 2943               best pork chops marinade ever
# 8443                          creole style chili
# 26195    stuffed portabella mushrooms  raw vegan
# 22457    revised betty crocker pineapple chutney
# 539                   almond rhubarb coffee cake
# 8767          crostini with honey and gorgonzola
# 10678          fabulous orange choc chip muffins
# 504                           almond coconut joy
# 26052            strawberry nut pinwheel cookies
# 2593                       beef and bows alfredo
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
rew = rew.set_index(np.arange(0, rew.shape[0]))

# %%
rew.index = np.arange(0, rew.shape[0])

# %%
rew
# Out:
#            user_id  recipe_id        date  rating  \
# 0            21752      57993  2003-05-01       5
# 1           431813     142201  2007-09-16       5
# 2           400708     252013  2008-01-10       4
# 3       2001852463     404716  2017-12-11       5
# 4            95810     129396  2008-03-14       5
# ...            ...        ...         ...     ...
# 126691     1270706     335534  2009-05-17       4
# 126692     2282344       8701  2012-06-03       0
# 126693      689540     222001  2008-04-08       5
# 126694  2000242659     354979  2015-06-02       5
# 126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
res[(res['minutes'] <= 20) & (res['n_ingredients'] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
res['submitted'] = pd.to_datetime(res['submitted'])
res.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %%
res = pd.read_csv('downloads/labs/recipes_sample.csv', parse_dates=['submitted'])

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
res[res['submitted'] < np.datetime64('2011-01-01')]

#res[np.array(list(res['submitted'].str.split('-')), dtype=np.int64)[:, 0] <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
res['description_length'] = res['description'].str.len()
res
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
res['name'] = res['name'].str.lstrip('0123456789.- ')
res
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
res['name_word_count'] = res['name'].str.split().str.len()
res
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ## Лабораторная работа №2.2

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
dt = res.groupby(['contributor_id']).count()[['id']]
dt
# Out:
#                  id
# contributor_id
# 1530              5
# 1533            186
# 1534             50
# 1535             40
# 1538              8
# ...             ...
# 2001968497        2
# 2002059754        1
# 2002234079        1
# 2002234259        1
# 2002247884        1
#
# [8404 rows x 1 columns]

# %%
dt.iloc[[np.argmax(dt)]]
# Out:
#                  id
# contributor_id
# 89831           421

# %%
dt.idxmax()
# Out:
# id    89831
# dtype: int64

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
rew2 = rew.groupby(['recipe_id']).mean(numeric_only=True)[['rating']]
rew2
# Out:
#                rating
# recipe_id
# 48                1.0
# 55               4.75
# 66        4.944444444
# 91               4.75
# 94                5.0
# ...               ...
# 536547            5.0
# 536610            0.0
# 536728            4.0
# 536729           4.75
# 536747            0.0
#
# [28100 rows x 1 columns]

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
res.groupby(pd.DatetimeIndex(res['submitted']).year).count()[['id']]
# Out:
#              id
# submitted
# 1999        275
# 2000        104
# 2001        589
# 2002       2644
# 2003       2334
# 2004       2153
# 2005       3130
# 2006       3473
# 2007       4429
# 2008       4029
# 2009       2963
# 2010       1538
# 2011        922
# 2012        659
# 2013        490
# 2014        139
# 2015         42
# 2016         24
# 2017         39
# 2018         24

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
res51 = res.merge(rew, left_on=['id'], right_on=['recipe_id'])[['id', 'name', 'user_id', 'rating']]
res51
# Out:
#             id                                    name  user_id  rating
# 0        44123   george s at the cove  black bean soup   743566       5
# 1        44123   george s at the cove  black bean soup    76503       5
# 2        44123   george s at the cove  black bean soup    34206       5
# 3        67664      healthy for them  yogurt popsicles   494084       5
# 4        67664      healthy for them  yogurt popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             zydeco soup   305531       5
# 126692  486161                             zydeco soup  1271506       5
# 126693  486161                             zydeco soup   724631       5
# 126694  486161                             zydeco soup   133174       5
# 126695  298512  cookies by design   cookies on a stick   804234       1
#
# [126696 rows x 4 columns]

# %%
res51[res51['id'] == 102274]
# Out:
#             id                                               name  user_id  \
# 118730  102274  tsr version of t g i  friday s black bean soup...   366782
# 118731  102274  tsr version of t g i  friday s black bean soup...    56824
# 118732  102274  tsr version of t g i  friday s black bean soup...  1274045
# 118733  102274  tsr version of t g i  friday s black bean soup...   403028
# 118734  102274  tsr version of t g i  friday s black bean soup...     7108
# ...        ...                                                ...      ...
# 118933  102274  tsr version of t g i  friday s black bean soup...   232190
# 118934  102274  tsr version of t g i  friday s black bean soup...   223564
# 118935  102274  tsr version of t g i  friday s black bean soup...  1520634
# 118936  102274  tsr version of t g i  friday s black bean soup...  2783129
# 118937  102274  tsr version of t g i  friday s black bean soup...   285039
#
#         rating
# 118730       5
# 118731       5
# 118732       5
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
mrg52 = res.merge(rew.groupby('recipe_id').count()['review'], how = 'left', left_on = 'id', right_on = 'recipe_id')[['id','name','review']]
mrg52
# Out:
#            id                                          name  review
# 0       44123         george s at the cove  black bean soup     3.0
# 1       67664            healthy for them  yogurt popsicles     8.0
# 2       38798                  i can t believe it s spinach     3.0
# 3       35173                          italian  gut busters     1.0
# 4       84797      love is in the air  beef fondue   sauces     8.0
# ...       ...                                           ...     ...
# 29995  267661  zurie s holey rustic olive and cheddar bread     4.0
# 29996  386977          zwetschgenkuchen  bavarian plum cake     2.0
# 29997  103312   zwiebelkuchen   southwest german onion cake     6.0
# 29998  486161                                   zydeco soup     6.0
# 29999  298512        cookies by design   cookies on a stick     1.0
#
# [30000 rows x 3 columns]

# %%
mrg52 = mrg52.fillna(0)
mrg52[mrg52['id'] == 1144]
# Out:
#          id                        name  review
# 25816  1144  steak   tomato basil pasta     0.0

# %%
#NEXT CODE NOT WORKING!!!

# %%
mrg52 = res.merge(rew, left_on=['id'], right_on=['recipe_id'])[['id', 'name']]
mrg52[:3]
# Out:
#       id                                   name
# 0  44123  george s at the cove  black bean soup
# 1  44123  george s at the cove  black bean soup
# 2  44123  george s at the cove  black bean soup

# %%
mrg52['review_count'] = rew.groupby(['recipe_id']).count()[['review']]
mrg52 = mrg52.fillna(0)
mrg52[:3]
# Out:
#       id                                   name  review_count
# 0  44123  george s at the cove  black bean soup           0.0
# 1  44123  george s at the cove  black bean soup           0.0
# 2  44123  george s at the cove  black bean soup           0.0

# %%
mrg52.iloc[[0]]
# Out:
#       id                                   name  review_count
# 0  44123  george s at the cove  black bean soup           0.0

# %%
mrg52.iloc[[48]]
# Out:
#        id                        name  review_count
# 48  95926  say what   banana sandwich           2.0

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
mrg = res.merge(rew, left_on='id', right_on='recipe_id')[['id', 'submitted', 'rating']]
mrg[:3]
# Out:
#       id  submitted  rating
# 0  44123 2002-10-25       5
# 1  44123 2002-10-25       5
# 2  44123 2002-10-25       5

# %%
mrg[['rating']].groupby(pd.DatetimeIndex(mrg['submitted']).year).mean(numeric_only=True).sort_values('rating')
# Out:
#                rating
# submitted
# 2017             2.75
# 2018      3.388888889
# 2016      3.538461538
# 2015      4.207317073
# 1999      4.274894811
# 2000       4.28458498
# 2013      4.336507937
# 2009      4.360447022
# 2011       4.37585034
# 2008      4.387415689
# 2001      4.393945429
# 2002      4.404645306
# 2010      4.406278855
# 2005      4.409687425
# 2012      4.412735849
# 2006      4.416309734
# 2007      4.420073281
# 2003       4.43915212
# 2004      4.463777632
# 2014      4.538235294

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
res = res.sort_values('name_word_count', ascending=False)
res[:3]
# Out:
#                                                     name      id  minutes  \
# 26223  subru uncle s whole green moong dal i ll be ma...   77188       95
# 27876  top secret recipes version of  i h o p  griddl...  113346       20
# 28083  tsr version of t g i  friday s black bean soup...  102274       75
#
#        contributor_id  submitted  n_steps  \
# 26223            6357 2003-11-21      NaN
# 27876          175727 2005-03-14      5.0
# 28083           74652 2004-10-19      9.0
#
#                                              description  n_ingredients  \
# 26223  my dad and mom quite enjoy this lentil curry. ...           15.0
# 27876  this recipe is top secret recipes version of i...            9.0
# 28083  from www.topsecretrecipes.com i got this copyc...           16.0
#
#        description_length  name_word_count
# 26223               343.0               15
# 27876               129.0               14
# 28083               436.0               14

# %%
res.to_csv('downloads/labs/some_data_ex.csv', index=True, sep=',')

# %%
pd.read_csv('downloads/labs/some_data_ex.csv', sep=',', index_col=0)[:3]
# Out:
#                                                     name      id  minutes  \
# 26223  subru uncle s whole green moong dal i ll be ma...   77188       95
# 27876  top secret recipes version of  i h o p  griddl...  113346       20
# 28083  tsr version of t g i  friday s black bean soup...  102274       75
#
#        contributor_id   submitted  n_steps  \
# 26223            6357  2003-11-21      NaN
# 27876          175727  2005-03-14      5.0
# 28083           74652  2004-10-19      9.0
#
#                                              description  n_ingredients  \
# 26223  my dad and mom quite enjoy this lentil curry. ...           15.0
# 27876  this recipe is top secret recipes version of i...            9.0
# 28083  from www.topsecretrecipes.com i got this copyc...           16.0
#
#        description_length  name_word_count
# 26223               343.0               15
# 27876               129.0               14
# 28083               436.0               14

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter('downloads/labs/pd.ExcelWriter.xlsx') as writer:
    res51.to_excel(writer, sheet_name='Рецепты с оценками')
    mrg52.to_excel(writer, sheet_name='Количество отзывов по рецептам')

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
